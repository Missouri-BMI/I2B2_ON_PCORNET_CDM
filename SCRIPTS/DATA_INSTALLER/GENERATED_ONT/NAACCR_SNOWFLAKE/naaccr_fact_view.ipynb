# %%
import pandas as pd
import os
import datetime
from dotenv import dotenv_values
import snowflake.connector as sc
import snowflake.connector.pandas_tools as snp
import re

# %%
config = dotenv_values(os.path.join(os.getcwd(),'env','sandbox','.env'))

con = sc.connect(
    user = config["USERNAME"],
    password = config["PASSWORD"],
    account = config["ACCOUNT"],
    warehouse = config["WAREHOUSE"],
    role = config["ROLE"],
    database = config["TARGET_DB"],
    schema = config["TARGET_SCHEMA"]
)
# Create a cursor object
cur = con.cursor()

# %%
# Fetch the column names
query = f"""
SELECT column_name from DEIDENTIFIED_PCORNET_CDM.information_schema.columns
    where 
        table_name = 'DEID_TUMOR' 
        and table_schema = 'CDM'
        and lower(column_name) like lower('%_N%') 
        and lower(column_name) not like lower('RAW_%')
        and data_type = 'TEXT';
"""
cur.execute(query)
columns = cur.fetchall()
columns_to_exclude = {'DATE_CASE_INITIATED_N2085','DATE_CASE_COMPLETED_N2090', 'PATID'}
column_list = [col[0] for col in columns if col[0] not in columns_to_exclude]

# # Construct the list of column names
column_list_str = ", ".join(column_list)
column_list_str
# Out:
# 'SECONDARY_DIAGNOSIS8_N3794, HISTOLOGY_ICD_O2_N420, RX_SUMM_SURG_PRIM_SITE_N1290, AJCC_TNM_POST_THERAPY_T_N1033, MEDICAL_RECORD_NUMBER_N2300, OVER_RIDE_SS_TNM_M_N1983, LN_HEAD_AND_NECK_LEVELS_N3877, MULTIGENE_SIGNATURE_RES_N3895, OVER_RIDE_HOSPSEQ_DXCON_N1986, CENSUS_TRACT2010_N135, AJCC_TNM_POST_THERAPY_S_N1024, RX_SUMM_SYSTEMIC_SUR_SE_N1639, PATH_REPORT_TYPE2_N7481, HER2_ISH_SUMMARY_N3854, PHASE1_RADIATION_TO_DRA_N1505, RAD_TREATMENT_VOLUME_N1540, LONGITUDE_N2354, TNM_EDITION_NUMBER_N1060, TNM_CLIN_DESCRIPTOR_N980, TUMOR_MARKER2_N1160, TNM_CLIN_M_N960, TEXT_HISTOLOGY_TITLE_N2590, RX_SUMM_RAD_TO_CNS_N1370, PERITONEAL_CYTOLOGY_N3911, GRADE_CLINICAL_N3843, PSA_LAB_VALUE_N3920, SECONDARY_DIAGNOSIS2_N3782, NUMBER_OF_POSITIVE_PARA_N3901, SCHEMA_DISCRIMINATOR2_N3927, CS_SITE_SPECIFIC_FACTOR_N2879, SEPARATE_TUMOR_NODULES_N3929, OVER_RIDE_CS14_N3763, CENSUS_BLOCK_GRP197090_N368, LN_DISTANT_MEDIASTINAL__N3875, RX_HOSP_SURG_APP2010_N668, ADDR_CURRENT_POSTAL_COD_N1830, SENTINEL_LYMPH_NODES_PO_N835, OVER_RIDE_SITE_LAT_SEQN_N2010, RX_SUMM_SURG_OTH9802_N1648, OVER_RIDE_CS11_N3760, NAME_LAST_N2230, PATH_REPORT_NUMBER2_N7091, GRADE_PATH_SYSTEM_N449, MULTIPLICITY_COUNTER_N446, BIRTHPLACE_COUNTRY_N254, HIV_STATUS_N3859, PATH_ORDER_PHYS_LIC_NO5_N7104, RACE5_N164, EOD_LYMPH_NODE_INVOLV_N810, RX_DATE_BRM_FLAG_N1241, GLEASON_PATTERNS_CLINIC_N3838, OVER_RIDE_CS12_N3761, TUMOR_MARKER1_N1150, COMORBID_COMPLICATION7_N3161, NPI_PHYSICIAN_PRIMARY_S_N2485, AFP_PRE_ORCHIECTOMY_RAN_N3808, DERIVED_PRERX7_N_N3450, ONCOTYPE_DX_RECURRENCE__N3904, DATE_OF_MULT_TUMORS_FLA_N439, NAME_MAIDEN_N2390, CIRCUMFERENTIAL_RESECTI_N3823, DERIVED_AJCC7_T_N3400, TEXT_USUAL_INDUSTRY_N320, DERIVED_PRERX7_T_N3440, SUBSQ_RX2ND_REG_LN_REM_N1679, OVER_RIDE_AGE_SITE_MORP_N1990, COMORBID_COMPLICATION5_N3150, DATE_OF_BIRTH_FLAG_N241, DERIVED_AJCC7_T_DESCRIP_N3402, TUMOR_DEPOSITS_N3934, SEER_SUMMARY_STAGE1977_N760, NPI_REGISTRY_ID_N45, RX_SUMM_SURGICAL_MARGIN_N1320, RECORD_NUMBER_RECODE_N1775, DERIVED_AJCC6_M_DESCRIP_N2990, SECONDARY_DIAGNOSIS7_N3792, NUMBER_OF_EXAMINED_PARA_N3899, METS_AT_DX_LIVER_N1115, RX_SUMM_PALLIATIVE_PROC_N3270, AJCC_TNM_PATH_T_SUFFIX_N1032, ADDR_AT_DX_SUPPLEMENTL_N2335, EOD_OLD2_DIGIT_N850, OVER_RIDE_REPORT_SOURCE_N2050, TUMOR_RECORD_NUMBER_N60, PHASE1_RADIATION_TREATM_N1506, AJCC_TNM_POST_THERAPY_M_N1023, OVER_RIDE_SS_TNM_N_N1982, PLEURAL_EFFUSION_N3913, OVER_RIDE_TNM_TIS_N1993, SUBSQ_RX2ND_SCOPE_LN_SU_N1677, OVER_RIDE_SITE_LAT_MORP_N2074, CS_SITE_SPECIFIC_FACTOR_N2865, OVER_RIDE_SITE_BEHAVIOR_N2071, CS_SITE_SPECIFIC_FACTOR_N2861, PHASE1_TOTAL_DOSE_N1507, MEASURED_THICKNESS_N3888, SUBSQ_RX3RD_COURSE_RAD_N1692, AJCC_TNM_POST_THERAPY_T_N1021, URIC2000_N345, SEER_SITE_SPECIFIC_FACT_N3704, SUBSQ_RX2ND_COURSE_OTH_N1676, FOLLOW_UP_SOURCE_N1790, CENSUS_IND_CODE2010_N272, NPCR_DERIVED_PATH_STG_G_N3655, SUBSQ_RX3RDCRS_DATE_FLA_N1681, TEXT_DX_PROC_SCOPES_N2540, DERIVED_AJCC6_T_DESCRIP_N2950, RX_TEXT_BRM_N2660, MEASURED_BASAL_DIAMETER_N3887, TEXT_PRIMARY_SITE_TITLE_N2580, CS_SITE_SPECIFIC_FACTOR_N2890, COUNTY_CURRENT_N1840, CS_SITE_SPECIFIC_FACTOR_N2910, SEER_CAUSE_SPECIFIC_COD_N1914, CS_VERSION_DERIVED_N2936, CODING_SYSTEM_FOR_EOD_N870, COUNTY_AT_DX_N90, CS_SITE_SPECIFIC_FACTOR_N2880, CRC_CHECKSUM_N2081, HISTOLOGIC_TYPE_ICD_O3_N522, MULT_TUM_RPT_AS_ONE_PRI_N444, RURALURBAN_CONTINUUM201_N3312, SOCIAL_SECURITY_NUMBER_N2320, SUBSQ_RX3RD_REG_LN_REM_N1699, DERIVED_PRERX7_M_DESCRI_N3462, EXTRANODAL_EXTENSION_CL_N3830, MICROVASCULAR_DENSITY_N3891, PATH_REPORT_TYPE3_N7482, RX_SUMM_BRM_N1410, ADDR_CURRENT_SUPPLEMENT_N2355, DERIVED_SUMMARY_STAGE20_N762, DERIVED_AJCC6_STAGE_GRP_N3000, RX_SUMM_OTHER_N1420, LN_ASSESSMENT_METHOD_PA_N3872, RX_CODING_SYSTEM_CURREN_N1460, PHASE1_DOSE_PER_FRACTIO_N1501, SUBSQ_RX4TH_COURSE_BRM_N1715, CS_SITE_SPECIFIC_FACTOR_N2870, RX_SUMM_TREATMENT_STATU_N1285, TUMOR_GROWTH_PATTERN_N3935, PATH_ORDERING_FAC_NO3_N7192, PHASE3_NUMBER_OF_FRACTI_N1523, ADENOPATHY_N3804, CS_SITE_SPECIFIC_FACTOR_N2920, ARCHIVE_FIN_N3100, CENSUS_TRACT2020_N125, OVER_RIDE_CS17_N3 ...

# %%
# Construct the unpivot SQL query

# Table name
table_name = 'TUMOR_FACT'
# source = 'DEIDENTIFIED_PCORNET_CDM.CDM.DEID_TUMOR'
source = 'CDM_DATALAKE.GPC.GPC_DEID_TUMOR'

unpivot_query = f"""
CREATE OR REPLACE VIEW {table_name} AS
(
    select 
        -1 :: NUMBER(38, 0)                                                                              as ENCOUNTER_NUM
        ,PATID :: NUMBER(38, 0)                                                                          as PATIENT_NUM
        ,concat('NAACCR|', split_part(concept, '_N', -1), ':', coalesce(concept_cd, ''))                 as CONCEPT_CD
        ,'@'                                                                                             as PROVIDER_ID
        ,DATE_CASE_INITIATED_N2085 :: TIMESTAMP                                                          as START_DATE
        ,'@'                                                                                             as MODIFIER_CD
        ,1                                                                                               as INSTANCE_NUM
        ,''                                                                                              as VALTYPE_CD
        ,''                                                                                              as TVAL_CHAR
        ,cast(null as  integer)                                                                          as NVAL_NUM
        ,''                                                                                              as VALUEFLAG_CD
        ,cast(null as  integer)                                                                          as QUANTITY_NUM
        ,'@'                                                                                             as UNITS_CD
        ,cast(DATE_CASE_COMPLETED_N2090 as TIMESTAMP)                                                    as END_DATE
        ,'@'                                                                                             as LOCATION_CD
        ,cast(null as  text)                                                                             as OBSERVATION_BLOB
        ,cast(null as  integer)                                                                          as CONFIDENCE_NUM
        ,CURRENT_TIMESTAMP                                                                               as UPDATE_DATE
        ,CURRENT_TIMESTAMP                                                                               as DOWNLOAD_DATE
        ,CURRENT_TIMESTAMP                                                                               as IMPORT_DATE
        ,cast(null as VARCHAR(50))                                                                       as SOURCESYSTEM_CD
        ,cast(null as  integer)                                                                          as UPLOAD_ID
    from DEIDENTIFIED_PCORNET_CDM.CDM.DEID_TUMOR
    unpivot (
        concept_cd for concept IN ({column_list_str})
    )
    order by patid
)
union all
(
    select 
        -1 :: NUMBER(38, 0)                                                                              as ENCOUNTER_NUM
        ,PATID :: NUMBER(38, 0)                                                                          as PATIENT_NUM
        ,concat('NAACCR|MORPH:',histologic_type_icd_o3_n522, '/',behavior_code_icd_o3_n523)              as CONCEPT_CD
        ,'@'                                                                                             as PROVIDER_ID
        ,DATE_CASE_INITIATED_N2085 :: TIMESTAMP                                                          as START_DATE
        ,'@'                                                                                             as MODIFIER_CD
        ,1                                                                                               as INSTANCE_NUM
        ,''                                                                                              as VALTYPE_CD
        ,''                                                                                              as TVAL_CHAR
        ,cast(null as  integer)                                                                          as NVAL_NUM
        ,''                                                                                              as VALUEFLAG_CD
        ,cast(null as  integer)                                                                          as QUANTITY_NUM
        ,'@'                                                                                             as UNITS_CD
        ,cast(DATE_CASE_COMPLETED_N2090 as TIMESTAMP)                                                    as END_DATE
        ,'@'                                                                                             as LOCATION_CD
        ,cast(null as  text)                                                                             as OBSERVATION_BLOB
        ,cast(null as  integer)                                                                          as CONFIDENCE_NUM
        ,CURRENT_TIMESTAMP                                                                               as UPDATE_DATE
        ,CURRENT_TIMESTAMP                                                                               as DOWNLOAD_DATE
        ,CURRENT_TIMESTAMP                                                                               as IMPORT_DATE
        ,cast(null as VARCHAR(50))                                                                       as SOURCESYSTEM_CD
        ,cast(null as  integer)                                                                          as UPLOAD_ID
    from {source}
)
;
"""
unpivot_query
# Out:
# "\nCREATE OR REPLACE VIEW TUMOR_FACT AS\n(\n    select \n        -1 :: NUMBER(38, 0)                                                                              as ENCOUNTER_NUM\n        ,PATID :: NUMBER(38, 0)                                                                          as PATIENT_NUM\n        ,concat('NAACCR|', split_part(concept, '_N', -1), ':', coalesce(concept_cd, ''))                 as CONCEPT_CD\n        ,'@'                                                                                             as PROVIDER_ID\n        ,DATE_CASE_INITIATED_N2085 :: TIMESTAMP                                                          as START_DATE\n        ,'@'                                                                                             as MODIFIER_CD\n        ,1                                                                                               as INSTANCE_NUM\n        ,''                                                                                              as VALTYPE_CD\n        ,''                                                                                              as TVAL_CHAR\n        ,cast(null as  integer)                                                                          as NVAL_NUM\n        ,''                                                                                              as VALUEFLAG_CD\n        ,cast(null as  integer)                                                                          as QUANTITY_NUM\n        ,'@'                                                                                             as UNITS_CD\n        ,cast(DATE_CASE_COMPLETED_N2090 as TIMESTAMP)                                                    as END_DATE\n        ,'@'                                                                                             as LOCATION_CD\n        ,cast(null as  text)                                                                             as OBSERVATION_BLOB\n        ,cast(null as  integer)                                                                          as CONFIDENCE_NUM\n        ,CURRENT_TIMESTAMP                                                                               as UPDATE_DATE\n        ,CURRENT_TIMESTAMP                                                                               as DOWNLOAD_DATE\n        ,CURRENT_TIMESTAMP                                                                               as IMPORT_DATE\n        ,cast(null as VARCHAR(50))                                                                       as SOURCESYSTEM_CD\n        ,cast(null as  integer)                                                                          as UPLOAD_ID\n    from DEIDENTIFIED_PCORNET_CDM.CDM.DEID_TUMOR\n    unpivot (\n        concept_cd for concept IN (SECONDARY_DIAGNOSIS8_N3794, HISTOLOGY_ICD_O2_N420, RX_SUMM_SURG_PRIM_SITE_N1290, AJCC_TNM_POST_THERAPY_T_N1033, MEDICAL_RECORD_NUMBER_N2300, OVER_RIDE_SS_TNM_M_N1983, LN_HEAD_AND_NECK_LEVELS_N3877, MULTIGENE_SIGNATURE_RES_N3895, OVER_RIDE_HOSPSEQ_DXCON_N1986, CENSUS_TRACT2010_N135, AJCC_TNM_POST_THERAPY_S_N1024, RX_SUMM_SYSTEMIC_SUR_SE_N1639, PATH_REPORT_TYPE2_N7481, HER2_ISH_SUMMARY_N3854, PHASE1_RADIATION_TO_DRA_N1505, RAD_TREATMENT_VOLUME_N1540, LONGITUDE_N2354, TNM_EDITION_NUMBER_N1060, TNM_CLIN_DESCRIPTOR_N980, TUMOR_MARKER2_N1160, TNM_CLIN_M_N960, TEXT_HISTOLOGY_TITLE_N2590, RX_SUMM_RAD_TO_CNS_N1370, PERITONEAL_CYTOLOGY_N3911, GRADE_CLINICAL_N3843, PSA_LAB_VALUE_N3920, SECONDARY_DIAGNOSIS2_N3782, NUMBER_OF_POSITIVE_PARA_N3901, SCHEMA_DISCRIMINATOR2_N3927, CS_SITE_SPECIFIC_FACTOR_N2879, SEPARATE_TUMOR_NODULES_N3929, OVER_RIDE_CS14_N3763, CENSUS_BLOCK_GRP197090_N368, LN_DISTANT_MEDIASTINAL__N3875, RX_HOSP_SURG_APP2010_N668, ADDR_CURRENT_POSTAL_COD_N1830, SENTINEL_LYMPH_NODES_PO_N835, OVER_RIDE_SITE_LAT_SEQN_N2010, RX_SUMM_SURG_OTH9802_N1648, OVER_RIDE_CS11_N3760, NAME_LAST_N2230, PATH_REPORT_NUMBER2_N7091, GRADE_PATH_SYSTEM_N449, MULTIPLICITY_COUNTER_N446, ...

# %%
# inner join {target_schema}.patient_crosswalk as pc
# using (patid)
# inner join {target_schema}.encounter_crosswalk as ec
# using (ENCOUNTERID);

# %%
# Execute the unpivot SQL query
# cur.execute(f"DROP TABLE IF EXISTS {database_name}.{schema_name}.{table_name}")
cur.execute(unpivot_query)

# Close the cursor and connection
cur.close()
con.close()

print("View created successfully.")
# Out:
# View created successfully.

# %%
run_con = sc.connect(
    user = config["USERNAME"],
    password = config["PASSWORD"],
    account = config["ACCOUNT"],
    warehouse = config["WAREHOUSE"],
    role = config["ROLE"],
    database = config["TARGET_DB"],
    schema = config["METADATA_SCHEMA"]
)
# Create a cursor object
run_cur = run_con.cursor()

run_cur.execute(f"call RUNTOTALNUM( 'TUMOR_FACT', 'I2B2DATA', 'NAACCR_ONTOLOGY')")
